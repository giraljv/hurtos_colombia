# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import utils.paths as path

# %%
data_dir = path.make_dir_function('data')

# %%
df_hurtos = pd.read_csv(data_dir('pre_process','hurtos.csv'),sep=',')

# %%
df_hurtos
# Out:
#        DIRECTORIO  NRO_ENCUESTA  SECUENCIA_ENCUESTA  SECUENCIA_P  ORDEN  \
# 0          400200           237                   3            1      3
# 1          400202           237                   2            1      2
# 2          400202           237                   3            1      3
# 3          400203           237                   1            1      1
# 4          400206           237                   1            1      1
# ...           ...           ...                 ...          ...    ...
# 16251      648845           237                   1            1      1
# 16252      648845           237                   2            1      2
# 16253      648914           237                   2            1      2
# 16254      648933           237                   3            1      3
# 16255      649001           237                   3            1      3
#
#                   FEX_C mes_ultimo_unico_robo       municipio      metodo  \
# 0      899,160107631136                 marzo  este municipio      atraco
# 1      752,987737425841                 junio  este municipio      atraco
# 2      752,987737425841             diciembre  este municipio    descuido
# 3      844,041463472488                  mayo  este municipio      atraco
# 4      814,000933778796               octubre  este municipio      atraco
# ...                 ...                   ...             ...         ...
# 16251  1894,00357738321                 junio  este municipio    descuido
# 16252  1894,00357738321                  mayo  este municipio      atraco
# 16253   213,65003726575                 marzo  este municipio  cosquilleo
# 16254   414,20264221387            septiembre  este municipio      fleteo
# 16255  195,498740904456                 julio  este municipio    descuido
#
#          hora  ... hizo_llamada denuncia      lugar_denuncia autoridad  \
# 0       noche  ...           no       no                 NaN       NaN
# 1       noche  ...           no       no                 NaN       NaN
# 2       noche  ...           no       si  denuncias en línea   policia
# 3       noche  ...           si       si            Fiscalía  fiscalia
# 4       noche  ...           no       si            Fiscalía  fiscalia
# ...       ...  ...          ...      ...                 ...       ...
# 16251   noche  ...           no       no                 NaN       NaN
# 16252  mañana  ...           no       no                 NaN       NaN
# 16253  mañana  ...           no       no                 NaN       NaN
# 16254   noche  ...           no       no                 NaN       NaN
# 16255  mañana  ...           no       no                 NaN       NaN
#
#           razon_denuncia buena_atencion razon_de_satisfaccion  \
# 0                    NaN            NaN                   NaN
# 1                    NaN            NaN                   NaN
# 2      evitar ocurrencia            NaN                   NaN
# 3               justicia             no      trato inadecuado
# 4       recuperar bienes             no        info imprecisa
# ...                  ...            ...                   ...
# 16251                NaN            NaN                   NaN
# 16252                NaN            NaN                   NaN
# 16253                NaN            NaN                   NaN
# 16254                NaN            NaN                   NaN
# 16255                NaN            NaN                   NaN
#
#                  razon_no_denuncia recuperacion_objeto  year
# 0            consideró innecesario                  no  2018
# 1      desconfianza en la justicia                  no  2018
# 2                              NaN                  no  2018
# 3                              NaN                  no  2018
# 4                              NaN                  no  2018
# ...                            ...                 ...   ...
# 16251  desconocimiento del proceso                  no  2020
# 16252  desconocimiento del proceso                  no  2020
# 16253  desconfianza en la justicia                  no  2020
# 16254  desconfianza en la justicia                  si  2020
# 16255          trámites engorrosos                  no  2020
#
# [16256 rows x 31 columns]
